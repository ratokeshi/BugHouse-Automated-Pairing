# %% [markdown]
# <a href="https://colab.research.google.com/github/ratokeshi/BugHouse-Automated-Pairing/blob/master/Bughouse_pairing_seats_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import itertools
import datetime
from collections import defaultdict
seats4 = [2,3,5,7]
seats8 = [2,3,5,7,11,13,17,19]
partners = []
opponents = []
rounds_list=[]
i=0
txtPairingAre = "The pairing options is: "
seperator = ","
print ("***********************************")
print(datetime.datetime.now())
print ("***********************************")
print("This is a bughouse set of 4: " + str(seats4) + str("\r\n"))

#   To print an element of the list.  In this case element 2
#       print (seats4[2])

print("This is a bughouse set of 8: " + str(seats8) + str("\r\n"))
print("This is the current partners set: " + str(partners) + str("\r\n"))
print("This is the current opponents set: " + str(opponents) + str("\r\n"))
#print (partners)
#print(opponents)
pairingresult = ()
#p = defaultdict(pairingresult)
print(pairingresult)
#print("The player number is: " + str(len(seats8)))
print ("***********************************")
#x = seats4[0]
#print (x)


#toggle this for 4 or 8 players
for s in itertools.permutations(seats4):
#for s in itertools.permutations(seats8):    
    
    #print ("Round: " + s + " - Seats are: " + s[0])
    
    paira = s[0] * s[1]
    pairb = s[2] * s[3]
    if len(s) > 4:
        pairc = s[4] * s[5]
        paird = s[6] * s[7]
       
    opp02 = s[0] * s[2]
    opp03 = s[0] * s[3] 
    opp12 = s[1] * s[2]
    opp13 = s[1] * s[3]
    if len(s) > 4:
        opp46 = s[4] * s[6]
        opp47 = s[4] * s[7] 
        opp56 = s[5] * s[6]
        opp57 = s[5] * s[7]
    
    print ("\nThe number of players in this tournament is : "+ str(len(s)))
    print (" ".join(map(str, s)))


    if partners.count(paira) < 2 and partners.count(pairb) < 2:
        print ("Pair A or B partner count: " + str(partners.count(paira)) + " or " + str(partners.count(pairb)) + " -> both less than 2 so appending pair A and B: values are: " + str(paira) + " , " + str(pairb))
        partners.append(paira)
        partners.append(pairb)
        #pairingresult[i] = s 
        rounds_list.append(s)
        print (rounds_list)
    else:
        print (str(paira) + " and/or " + str(pairb) + " count in list " +  str(partners.count(paira)) + " or " + str(partners.count(pairb)) + " count in list is 2 or more.")        
        print (" ".join(map(str, s)) + " is not a valid new seating arangement.\n")
    #if pairb != 0 and partners.count(pairb)< 2:
    #    print ("Pair B partner count is " + str(partners.count(pairb)) + " -> less than 2 so appending pair B: B value is = " + str(pairb))
    #    partners.append(pairb)
    #else:
    #    print (str(pairb) + " is either 0 or count in list " +  str(partners.count(pairb)) + " is 2 or more.") 



    #if pairc != 0:
    #    partners.append(pairc)
    #if paird != 0:
    #    partners.append(paird)        
    print(partners)
# Out:
# ***********************************
# 2019-07-07 21:30:51.652955
# ***********************************
# This is a bughouse set of 4: [2, 3, 5, 7]
#
# This is a bughouse set of 8: [2, 3, 5, 7, 11, 13, 17, 19]
#
# This is the current partners set: []
#
# This is the current opponents set: []
#
# ()
# ***********************************
#
# The number of players in this tournament is : 4
# 2 3 5 7
# Pair A or B partner count: 0 or 0 -> both less than 2 so appending pair A and B: values are: 6 , 35
# [(2, 3, 5, 7)]
# [6, 35]
#
# The number of players in this tournament is : 4
# 2 3 7 5
# Pair A or B partner count: 1 or 1 -> both less than 2 so appending pair A and B: values are: 6 , 35
# [(2, 3, 5, 7), (2, 3, 7, 5)]
# [6, 35, 6, 35]
#
# The number of players in this tournament is : 4
# 2 5 3 7
# Pair A or B partner count: 0 or 0 -> both less than 2 so appending pair A and B: values are: 10 , 21
# [(2, 3, 5, 7), (2, 3, 7, 5), (2, 5, 3, 7)]
# [6, 35, 6, 35, 10, 21]
#
# The number of players in this tournament is : 4
# 2 5 7 3
# Pair A or B partner count: 1 or 1 -> both less than 2 so appending pair A and B: values are: 10 , 21
# [(2, 3, 5, 7), (2, 3, 7, 5), (2, 5, 3, 7), (2, 5, 7, 3)]
# [6, 35, 6, 35, 10, 21, 10, 21]
#
# The number of players in this tournament is : 4
# 2 7 3 5
# Pair A or B partner count: 0 or 0 -> both less than 2 so appending pair A and B: values are: 14 , 15
# [(2, 3, 5, 7), (2, 3, 7, 5), (2, 5, 3, 7), (2, 5, 7, 3), (2, 7, 3, 5)]
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15]
#
# The number of players in this tournament is : 4
# 2 7 5 3
# Pair A or B partner count: 1 or 1 -> both less than 2 so appending pair A and B: values are: 14 , 15
# [(2, 3, 5, 7), (2, 3, 7, 5), (2, 5, 3, 7), (2, 5, 7, 3), (2, 7, 3, 5), (2, 7, 5, 3)]
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 3 2 5 7
# 6 and/or 35 count in list 2 or 2 count in list is 2 or more.
# 3 2 5 7 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 3 2 7 5
# 6 and/or 35 count in list 2 or 2 count in list is 2 or more.
# 3 2 7 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 3 5 2 7
# 15 and/or 14 count in list 2 or 2 count in list is 2 or more.
# 3 5 2 7 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 3 5 7 2
# 15 and/or 14 count in list 2 or 2 count in list is 2 or more.
# 3 5 7 2 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 3 7 2 5
# 21 and/or 10 count in list 2 or 2 count in list is 2 or more.
# 3 7 2 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 3 7 5 2
# 21 and/or 10 count in list 2 or 2 count in list is 2 or more.
# 3 7 5 2 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 5 2 3 7
# 10 and/or 21 count in list 2 or 2 count in list is 2 or more.
# 5 2 3 7 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 5 2 7 3
# 10 and/or 21 count in list 2 or 2 count in list is 2 or more.
# 5 2 7 3 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 5 3 2 7
# 15 and/or 14 count in list 2 or 2 count in list is 2 or more.
# 5 3 2 7 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 5 3 7 2
# 15 and/or 14 count in list 2 or 2 count in list is 2 or more.
# 5 3 7 2 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 5 7 2 3
# 35 and/or 6 count in list 2 or 2 count in list is 2 or more.
# 5 7 2 3 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 5 7 3 2
# 35 and/or 6 count in list 2 or 2 count in list is 2 or more.
# 5 7 3 2 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 7 2 3 5
# 14 and/or 15 count in list 2 or 2 count in list is 2 or more.
# 7 2 3 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 7 2 5 3
# 14 and/or 15 count in list 2 or 2 count in list is 2 or more.
# 7 2 5 3 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 7 3 2 5
# 21 and/or 10 count in list 2 or 2 count in list is 2 or more.
# 7 3 2 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 7 3 5 2
# 21 and/or 10 count in list 2 or 2 count in list is 2 or more.
# 7 3 5 2 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 7 5 2 3
# 35 and/or 6 count in list 2 or 2 count in list is 2 or more.
# 7 5 2 3 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 4
# 7 5 3 2
# 35 and/or 6 count in list 2 or 2 count in list is 2 or more.
# 7 5 3 2 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
