# %% [markdown]
# <a href="https://colab.research.google.com/github/ratokeshi/BugHouse-Automated-Pairing/blob/master/Copy_of_Bughouse_pairing_seats_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import itertools
import datetime
from collections import defaultdict
seats4 = [2,3,5,7]
seats8 = [2,3,5,7,11,13,17,19]
partners = []
opponents = []
rounds_list=[]
i=0
txtPairingAre = "The pairing options is: "
seperator = ","
print ("***********************************")
print(datetime.datetime.now())
print ("***********************************")
print("This is a bughouse set of 4: " + str(seats4) + str("\r\n"))

#   To print an element of the list.  In this case element 2
#       print (seats4[2])

print("This is a bughouse set of 8: " + str(seats8) + str("\r\n"))
print("This is the current partners set: " + str(partners) + str("\r\n"))
print("This is the current opponents set: " + str(opponents) + str("\r\n"))
#print (partners)
#print(opponents)
pairingresult = ()
#p = defaultdict(pairingresult)
print(pairingresult)
#print("The player number is: " + str(len(seats8)))
print ("***********************************")
#x = seats4[0]
#print (x)


#toggle this for 4 or 8 players
#for s in itertools.permutations(seats4):
for s in itertools.permutations(seats8):    
    
    #print ("Round: " + s + " - Seats are: " + s[0])
    
    paira = s[0] * s[1]
    pairb = s[2] * s[3]
    if len(s) > 4:
        pairc = s[4] * s[5]
        paird = s[6] * s[7]
       
    opp02 = s[0] * s[2]
    opp03 = s[0] * s[3] 
    opp12 = s[1] * s[2]
    opp13 = s[1] * s[3]
    if len(s) > 4:
        opp46 = s[4] * s[6]
        opp47 = s[4] * s[7] 
        opp56 = s[5] * s[6]
        opp57 = s[5] * s[7]
    
    print ("\nThe number of players in this tournament is : "+ str(len(s)))
    print (" ".join(map(str, s)))


    if partners.count(paira) < 2 and partners.count(pairb) < 2:
        print ("Pair A or B partner count: " + str(partners.count(paira)) + " or " + str(partners.count(pairb)) + " -> both less than 2 so appending pair A and B: values are: " + str(paira) + " , " + str(pairb))
        partners.append(paira)
        partners.append(pairb)
        #pairingresult[i] = s 
        rounds_list.append(s)
        print (rounds_list)
    else:
        print (str(paira) + " and/or " + str(pairb) + " count in list " +  str(partners.count(paira)) + " or " + str(partners.count(pairb)) + " count in list is 2 or more.")        
        print (" ".join(map(str, s)) + " is not a valid new seating arangement.\n")
    #if pairb != 0 and partners.count(pairb)< 2:
    #    print ("Pair B partner count is " + str(partners.count(pairb)) + " -> less than 2 so appending pair B: B value is = " + str(pairb))
    #    partners.append(pairb)
    #else:
    #    print (str(pairb) + " is either 0 or count in list " +  str(partners.count(pairb)) + " is 2 or more.") 



    #if pairc != 0:
    #    partners.append(pairc)
    #if paird != 0:
    #    partners.append(paird)        
    print(partners)
# Out:
# ***********************************
# 2019-07-07 21:34:00.762401
# ***********************************
# This is a bughouse set of 4: [2, 3, 5, 7]
#
# This is a bughouse set of 8: [2, 3, 5, 7, 11, 13, 17, 19]
#
# This is the current partners set: []
#
# This is the current opponents set: []
#
# ()
# ***********************************
#
# The number of players in this tournament is : 8
# 2 3 5 7 11 13 17 19
# Pair A or B partner count: 0 or 0 -> both less than 2 so appending pair A and B: values are: 6 , 35
# [(2, 3, 5, 7, 11, 13, 17, 19)]
# [6, 35]
#
# The number of players in this tournament is : 8
# 2 3 5 7 11 13 19 17
# Pair A or B partner count: 1 or 1 -> both less than 2 so appending pair A and B: values are: 6 , 35
# [(2, 3, 5, 7, 11, 13, 17, 19), (2, 3, 5, 7, 11, 13, 19, 17)]
# [6, 35, 6, 35]
#
# The number of players in this tournament is : 8
# 2 3 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 5 19 17 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 11 5 17 19
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 11 5 17 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 11 5 19 17
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 11 5 19 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 11 17 5 19
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 11 17 5 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 11 17 19 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 11 17 19 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 11 19 5 17
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 11 19 5 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 11 19 17 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 11 19 17 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 17 5 11 19
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 17 5 11 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 17 5 19 11
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 17 5 19 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 17 11 5 19
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 17 11 5 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 17 11 19 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 17 11 19 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 17 19 5 11
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 17 19 5 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 17 19 11 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 17 19 11 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 19 5 11 17
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 19 5 11 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 19 5 17 11
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 19 5 17 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 19 11 5 17
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 19 11 5 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 19 11 17 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 19 11 17 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 19 17 5 11
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 19 17 5 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 13 19 17 11 5
# 14 and/or 39 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 13 19 17 11 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 5 11 13 19
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 5 11 13 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 5 11 19 13
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 5 11 19 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 5 13 11 19
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 5 13 11 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 5 13 19 11
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 5 13 19 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 5 19 11 13
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 5 19 11 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 5 19 13 11
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 5 19 13 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 11 5 13 19
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 11 5 13 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 11 5 19 13
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 11 5 19 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 11 13 5 19
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 11 13 5 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 11 13 19 5
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 11 13 19 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 11 19 5 13
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 11 19 5 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 11 19 13 5
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 11 19 13 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 13 5 11 19
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 13 5 11 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 13 5 19 11
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 13 5 19 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 13 11 5 19
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 13 11 5 19 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 13 11 19 5
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 13 11 19 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 13 19 5 11
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 13 19 5 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 13 19 11 5
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 13 19 11 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 19 5 11 13
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 19 5 11 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 19 5 13 11
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 19 5 13 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 19 11 5 13
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 19 11 5 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 19 11 13 5
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 19 11 13 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 19 13 5 11
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 19 13 5 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 17 19 13 11 5
# 14 and/or 51 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 17 19 13 11 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 5 11 13 17
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 5 11 13 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 5 11 17 13
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 5 11 17 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 5 13 11 17
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 5 13 11 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 5 13 17 11
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 5 13 17 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 5 17 11 13
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 5 17 11 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 5 17 13 11
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 5 17 13 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 11 5 13 17
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 11 5 13 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 11 5 17 13
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 11 5 17 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 11 13 5 17
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 11 13 5 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 11 13 17 5
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 11 13 17 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 11 17 5 13
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 11 17 5 13 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 11 17 13 5
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 11 17 13 5 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 13 5 11 17
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 13 5 11 17 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# 2 7 3 19 13 5 17 11
# 14 and/or 57 count in list 2 or 0 count in list is 2 or more.
# 2 7 3 19 13 5 17 11 is not a valid new seating arangement.
#
# [6, 35, 6, 35, 10, 21, 10, 21, 14, 15, 14, 15]
#
# The number of players in this tournament is : 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5212c78fabcb> in <module>()
#      55
#      56     print ("\nThe number of players in this tournament is : "+ str(len(s)))
# ---> 57     print (" ".join(map(str, s)))
#      58
#      59
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in write(self, string)
#     350             is_child = (not self._is_master_process())
#     351             # only touch the buffer in the IO thread to avoid races
# --> 352             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     353             if is_child:
#     354                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     184         """
#     185         if self.thread.is_alive():
# --> 186             event_id = os.urandom(16)
#     187             while event_id in self._events:
#     188                 event_id = os.urandom(16)
#
# KeyboardInterrupt:
